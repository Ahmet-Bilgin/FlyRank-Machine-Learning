# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmet-Bilgin/FlyRank-Machine-Learning/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ahmet-Bilgin/FlyRank-Machine-Learning/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Freestyle - Future Decline/Momentum Prediction
# *Reacting to traffic loss is useful, but predicting it before the drop becomes severe is much more valuable. I want to build a model that uses a strict "past window" of features (e.g., past 90 days) to predict a "future window" outcome*

# %%
# No code needed for this section. Answer is in the markdown cell above.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *The Search Question: Can we predict which currently stable pages are at high risk of declining in the near future based on their historical signals?*
#
# *Unit of Analysis: A single URL / web page evaluated over a specific time window.*
#
# *The Output: A ranked future-risk list with probability scores.*
#
# *The Action: The content team proactively updates and protects "at-risk" pages before the massive traffic loss actually happens.*
#
# *Cost of a Wrong Call: Wasting editorial resources on refreshing pages that were going to remain stable anyway, or missing the ones that actually crash.*

# %%
# No code needed for this section. Answer is in the markdown cell above.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Ahmet-Bilgin/FlyRank-Machine-Learning/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

total_records = len(df)
high_impression_pages = len(df[df['impressions_90d'] > 1000])

print(f"Total historical records available: {total_records}")
print(f"Pages with deep historical signal (>1000 impressions in 90d): {high_impression_pages}")

# Checking how many pages already have a baseline 'down' trend
declining = len(df[df['trend_direction'] == 'down'])
print(f"Pages currently flagged as declining: {declining}")
# Out:
# Total historical records available: 30000
# Pages with deep historical signal (>1000 impressions in 90d): 13509
# Pages currently flagged as declining: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *I can claim: "Pages exhibiting these specific signal patterns over a past 90-day window have a higher observed probability of declining in the subsequent period. This provides a directional early-warning system."*
#
# *I cannot claim: "This model perfectly predicts the future," or "This proves how search algorithms penalize older content."*
#
# *Crucial ML Note: I must strictly guard against data leakage; my features must only come from the 'past' window, and my target must only come from the 'future' window.*

# %%
# No code needed for this section. Answer is in the markdown cell above.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
